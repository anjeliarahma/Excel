# %% [markdown]
# # **Power Query - Import Data and Data Cleaning**

# %% [markdown]
# # **1. Format and Extract**
#
# **Instructions:**
# - Format and extract Table A using Power Query.
# - Separate the First Name and Last Name into different columns
# - Capitalizing each word.
# - Separate the Division and Position into different columns.
# - Create Employee Codes in the format K-88, K-42, etc.

# %% [markdown]
# **Table A**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Format and extract from Table A**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Split Column**
#
# **Instructions:**
# *   Use the source data from data.csv : https://drive.google.com/file/d/1J7byAee50ovrZ3CM6IUBuBNld47FljDE/view?usp=drive_link
# *   Split the following columns: Dept, ID, Name (without titles), Age, and Email (new format: firstname.initials@gosmile.com)

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result SplitColumn from data.csv**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Split Row**
#
# **Instructions:**
#
# - Split by rows: Type of Mainan (Toy), by Variasi Warna (Color Variaton)  and Harga (Price).
# - Then create a Pivot Table Report for each available color variation.
# - Use the source from data.pdf : https://drive.google.com/file/d/1wfIRHhOBl_-G1DGbswiv7vSeoH90cXI1/view?usp=drive_link

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Split Rows from data.pdf**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Pivot Table Report for each available color variation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Fill-Up and Fill-Down**
#
# **Instructions:**
# - Perform Fill Up/Fill Down on Table B using Power Query.
# - Then create a "Pivot Table Report" displaying the total training summary for each Department according to the training categories.

# %% [markdown]
# **Tabel B**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Fill-Up and Fill-Down from Tabel B**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Summary : Total Training  by Department

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **5. Remove Duplicates**
#
# **Instructions:**
#
# - Remove Duplicates on Table C using Power Query.
# - Remove duplicates from Dept/Name/Position and convert the Dept column to uppercase.
# - Sort rows by the Dept and Position columns.

# %% [markdown]
# **Tabel C**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Remove Duplicates from Tabel C**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **6. Append**
#
# Instructions:
# - Combine data from a folder (Append).
# - Use data from the "Multiple files" folder : https://drive.google.com/drive/folders/1lx0rOWeSUOgEkyZJf0YQXnopQCMhSYiP?usp=drive_link
# - Combine and transform the data, as well as cleanse it.
# - Display only the names that are registered and present.

# %% [markdown]
# **Applied Steps - Power Query**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Result Append from "Multiple files" folder**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Source
#
# *   DQLab Academy: BootCamp Data Analyst with Excel - Session 9 - Import Data External and Power Pivot using Power Query (Mentor: Adit Wijaya / Adithya - @bossexcel.id)
#
# *   Excel Version: [https://docs.google.com/spreadsheets/d/1idiATxB_uZ04LkufKvSLNZPa5aKSkrpX/edit?usp=sharing&ouid=106238708877822318719&rtpof=true&sd=true]
#
#
#
#
#
# ---
#
# <br>
# <a href="https://www.linkedin.com/in/anjeliarahma/"><img src="https://img.shields.io/badge/-© 2024  Anjelia Rahmawati-417DAC?style=for-the-badge&logoColor=white"/></a>
