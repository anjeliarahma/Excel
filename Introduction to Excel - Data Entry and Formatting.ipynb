# %% [markdown]
# # WorkbookWorksheet
#
# - WORKBOOK = EXCEL FILE (.xlsx, .xlsb)
# - WORKSHEET = the sheet where we input and process data, either with visual components and charts or with formulas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Column Width Adjustment**
#
# Pro Tips:
# - `Alt, H, O, I dan Alt, H, O, A`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CellReference
#
# - A cell address is a reference used to identify the location of a cell within a specific column and row.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Absolute**
#
# Pro Tip:
#
# Press the `F4` key or `Fn + F4`

# %% [markdown]
# # FlashFIll

# %% [markdown]
# - Manually enter data in Column `G6` according to the template between Column `D6` and Column `E6` with a hyphen `("-")` separator, resulting in `Atasan-T-Shirt`, then press `Enter`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - After pressing `Enter`, press `Ctrl + E`. The rows will automatically fill in as follows.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Number and Text

# %% [markdown]
# - To determine whether the format of the data is `text` or a `number`:
# - Formulas: `=ISTEXT` and `=ISNUMBER`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **`Custom - format cells`**
# - Contoh custom format cells for number `59100` into `59 Ribu`
#
# - Custom type : `[>=1000000000]#.##0,0..."M";[>=1000000]#.##0.."jt";#.##0."rb"`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Date and Time

# %% [markdown]
# **1. Date + Time**
#
# Formulas:
# - Day `=DAY(cell)`
# - Month `=MONTH(cell)`
# - Year `=YEAR(cell)`
# - Time `=TIME(cell)`
# - Hour `=HOUR(cell)`
# - Minute `=MINUTE(cell)`
# - Second `=SECOND(cell)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2. DATEIF**
#
# Formulas:
# - `=DATEIF(cell)`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example of calculating Years, Months, and Days by combining the formula `=DATEDIF` with `Y (Years)`, `YM (Months)`, and `MD (Days)`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. DATEVALUE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Sort Filter
#
# - Shortcut filter `Ctrl + Alt + L`
# - Short Ascending `Alt, A, SA`
# - Short Ascending `Alt, A, SD`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SubTotal
#
# - Formulas: `=SUBTOTAL`
# - Or you can use the option `Data - Subtotal`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example:
# - Creating a subtotal based on categories

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Text To Column

# %% [markdown]
# Example:
#
# - Converting data from CSV format
# - Select `Data`, then choose `Text to Columns`
# - Step 1: `Select Delimited` - then click `Next`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Step 2: Choose the delimiter that separates the data. In this example, the separator is the `"," (Comma)`. So, select `Comma` - then click `Next`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Step 3 will display a `Preview`. If everything looks correct, click `Finish`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - And the output will look like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Find Replace

# %% [markdown]
# Pro Tip:
# - Find `Ctrl + F`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pro Tip:
# - Replate `Ctrl + H`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CopyPaste
#
# Pro Tip:
# - Copy `Ctrl + C`
# - Paste `Ctrl + V`

# %% [markdown]
# CopyPaste option:

# %% [markdown]
# ![Screenshot 2024-11-11 165040.png](data:image/png;base64,...)

# %% [markdown]
# # FreezePanes

# %% [markdown]
# ![Screenshot 2024-11-11 165213.png](data:image/png;base64,...)

# %% [markdown]
# # Source Data
#
# * DQLab Academy: BootCamp Data Analyst with Excel - Sesi 1 - Introduction to Excel, Data Entry, and Formatting (Mentor: Rifki Taufik)
#
# *   Excel Version: [https://docs.google.com/spreadsheets/d/1evPM3F48FWHRtN7K-edHUoEoTuRr2KV-/edit?usp=sharing&ouid=106238708877822318719&rtpof=true&sd=true]
#
#
#
#
# ---
#
# <br>
# <a href="https://www.linkedin.com/in/anjeliarahma/"><img src="https://img.shields.io/badge/-© 2024 Anjelia Rahmawati-417DAC?style=for-the-badge&logoColor=white"/></a>
